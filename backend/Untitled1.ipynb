# %%
from scipy import stats

# %%
a=[1,2,3]
b=[9,5,7]
stats.wasserstein_distance(a,b)
# Out:
# 5.000000000000001

# %%
import pandas as pd
a=pd.Series(a)

# %%
b=pd.Series(b)
stats.wasserstein_distance(a,b)
# Out:
# 5.000000000000001

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
G = nx.Graph()
G.add_node("hello")
nx.draw(G,with_labels=True)
plt.draw()
plt.show()

# %%
G=nx.Graph()
G.add_nodes_from(range(10))
e = [(0,1),(0,2)]
G.add_edges_from(e)

# some labels
labels={}

nx.draw_circular(G, node_color='y', edge_color='#909090', node_size=500,labels=labels)

plt.axis('equal')
# Out:
# (-1.0999999812245371,
#  1.0999999991059304,
#  -1.0461620954516297,
#  1.0461622083036155)

# %%
import pandas as pd
df = pd.read_csv("c1.csv")

# %%
df1=df[(df['eType']<5)&(df1['eType']!=4)]

# %%
df1
# Out:
#      Source  eType  Target      Time  Weight  SourceLocation  TargetLocation  \
# 1        41      0      34     86400       1             NaN             NaN
# 2        37      0      27     94461       1             NaN             NaN
# 3        34      1      27    107548       1             5.0             5.0
# 4        41      0      37    127838       1             NaN             NaN
# 5        34      1      37    137358       1             5.0             5.0
# ..      ...    ...     ...       ...     ...             ...             ...
# 616      56      0      41  27135128       1             NaN             NaN
# 617      56      0      57  27150761       1             NaN             NaN
# 619      41      1      57  27160169       1             5.0             0.0
# 620      57      1      56  27205975       1             0.0             0.0
# 621      41      0      57  27222388       1             NaN             NaN
#
# ...

# %%
G = nx.from_pandas_edgelist(df1, 'Source', 'Target')
layout = nx.shell_layout(G)

people = list(df1[(df1['eType']==1)|(df1['eType']==0)]['Source'].unique())

people =people+( list(df1[df1['eType']<=1]['Target'].unique()))
people =people+( list(df1[df1['eType']==3]['Source'].unique()))
people=list(set(people))
print(people)
item = list(df1[df1['eType']==2]['Target'].unique())
item = item+ list(df1[df1['eType']==3]['Target'].unique())

item=list(set(item))
radii = [7,15,30,45,60]  # for concentric circles
label={}
for ea in layout.keys():
    new_r = 1
    if ea in  item:
        new_r = radii[0]
        label[ea]=""
    elif ea in people:
        new_r = radii[4]
        label[ea]=str(ea)
    else:
        pass
    layout[ea] *= new_r 
nx.draw_networkx_labels(G, layout,labels=label)
nx.draw_networkx_nodes(G, layout,
                       nodelist=people,
                       node_color='r',
                       node_size=300,
                       alpha=0.8,with_labels=False)

nx.draw_networkx_nodes(G, layout,
                       nodelist=item,
                       node_color='b',
                       node_size=400,
                       alpha=0.8)
nx.draw_networkx_edges(G, layout, width=1.0, alpha=0.5)

plt.axis('off')
#nx.draw(G, layout, width=1.0, alpha=0.5)
plt.show()
print(layout)
print(df1[df1['eType']==3])
# Out:
# [0, 65, 34, 67, 66, 37, 39, 40, 41, 43, 45, 47, 56, 57, 58, 27, 63]
# {41: array([6.00000000e+01, 1.88748047e-06]), 34: array([56.38155699, 20.52120924]), 37: array([45.96266627, 38.56725812]), 27: array([29.99999821, 51.96153045]), 40: array([10.41889429, 59.08846736]), 0: array([-10.41889071,  59.08846736]), 39: array([-30.00000358,  51.96152687]), 65: array([-45.96266627,  38.5672617 ]), 67: array([-56.38155699,  20.5212146 ]), 47: array([-6.00000000e+01, -3.35788613e-06]), 66: array([-56.38155699, -20.52120745]), 657187: array([-5.36231148, -4.49951261]), 43: array([-29.99999464, -51.96152329]), 56: array([-10.41888714, -59.08846378]), 57: array([ 10.41888982, -59.08846021]), 58: array([ 29.99999464, -51.96152329]), 63: array([ 45.96265912, -38.5672617 ]), 45: array([ 56.38155341, -20.52121997])}
#      Source  eType  Target      Time  Weight  SourceLocation  TargetLocation  \
# 174      39      3  657187   9519349     300             NaN             NaN
# ...

# %%
df2=df[(df['eType']==5)&(df['Source']>1000)]

# %%
df2
# Out:
#       Source  eType  Target      Time  Weight  SourceLocation  TargetLocation  \
# 636   510031      5       2  31536000     600             NaN             NaN
# 638   552988      5       2  31536000   40000             NaN             NaN
# 660   510031      5      27  31536000    1000             NaN             NaN
# 662   552988      5      27  31536000   50000             NaN             NaN
# 681   552988      5      29  31536000   30000             NaN             NaN
# ...      ...    ...     ...       ...     ...             ...             ...
# 1265  510031      5      64  31536000    1000             NaN             NaN
# 1267  552988      5      64  31536000   20000             NaN             NaN
# 1284  510031      5      65  31536000     300             NaN             NaN
# 1286  552988      5      65  31536000   10000             NaN             NaN
# 1308  552988      5       0  31536000   20000             NaN             NaN
#
# ...

# %%
import pandas as pd
df = pd.read_csv("./data/CGCS-Template.csv")
for ind in df.index: 
    if(df['eType'][ind]==5):
        if((df['Source'][ind]==510031)|(df['Source'][ind]==552988)):
            temp=df['Source'][ind]
            df['Source'][ind]=df['Target'][ind]
            df['Target'][ind]=temp
            print(df.iloc[ind])
# Out:
# <ipython-input-150-a0900506b4cc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Source'][ind]=df['Target'][ind]
# <ipython-input-150-a0900506b4cc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'][ind]=temp
# Source                    2.0
# eType                     5.0
# Target               510031.0
# Time               31536000.0
# Weight                  600.0
# SourceLocation            NaN
# TargetLocation            NaN
# SourceLatitude            NaN
# SourceLongitude           NaN
# TargetLatitude            NaN
# TargetLongitude           NaN
# Name: 636, dtype: float64
# ...

# %%
df.to_csv('CGCS-Templaterew.csv',index=False)

# %%
df = pd.read_csv("./data/Q1-Graph1.csv")
for ind in df.index: 
    if(df['eType'][ind]==5):
        if((df['Source'][ind]==510031)|(df['Source'][ind]==552988)):
            temp=df['Source'][ind]
            df['Source'][ind]=df['Target'][ind]
            df['Target'][ind]=temp
            print(df.iloc[ind])
df.to_csv('Q1-Graph1rew.csv',index=False)
# Out:
# <ipython-input-153-b4d86bfd7342>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Source'][ind]=df['Target'][ind]
# <ipython-input-153-b4d86bfd7342>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'][ind]=temp
# Source               608827.0
# eType                     5.0
# Target               552988.0
# Time               31536000.0
# Weight               143858.0
# SourceLocation            NaN
# TargetLocation            NaN
# SourceLatitude            NaN
# SourceLongitude           NaN
# TargetLatitude            NaN
# TargetLongitude           NaN
# Name: 371, dtype: float64
# ...

# %%
df = pd.read_csv("./data/Q1-Graph2.csv")
for ind in df.index: 
    if(df['eType'][ind]==5):
        if((df['Source'][ind]==510031)|(df['Source'][ind]==552988)):
            temp=df['Source'][ind]
            df['Source'][ind]=df['Target'][ind]
            df['Target'][ind]=temp
            print(df.iloc[ind])
df.to_csv('Q1-Graph2rew.csv',index=False)
# Out:
# <ipython-input-154-7fcdd25c10fc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Source'][ind]=df['Target'][ind]
# <ipython-input-154-7fcdd25c10fc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'][ind]=temp
# Source               604021.00
# eType                     5.00
# Target               510031.00
# Time               31536000.00
# Weight                  113.92
# SourceLocation             NaN
# TargetLocation             NaN
# SourceLatitude             NaN
# SourceLongitude            NaN
# TargetLatitude             NaN
# TargetLongitude            NaN
# ...

# %%
df = pd.read_csv("./data/Q1-Graph3.csv")
for ind in df.index: 
    if(df['eType'][ind]==5):
        if((df['Source'][ind]==510031)|(df['Source'][ind]==552988)):
            temp=df['Source'][ind]
            df['Source'][ind]=df['Target'][ind]
            df['Target'][ind]=temp
            print(df.iloc[ind])
df.to_csv('Q1-Graph3rew.csv',index=False)
# Out:
# <ipython-input-155-9ea6ae6b75b6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Source'][ind]=df['Target'][ind]
# <ipython-input-155-9ea6ae6b75b6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'][ind]=temp
# Source               610497.00
# eType                     5.00
# Target               552988.00
# Time               31536000.00
# Weight                 3704.63
# SourceLocation             NaN
# TargetLocation             NaN
# SourceLatitude             NaN
# SourceLongitude            NaN
# TargetLatitude             NaN
# TargetLongitude            NaN
# ...

# %%
df = pd.read_csv("./data/Q1-Graph4.csv")
for ind in df.index: 
    if(df['eType'][ind]==5):
        if((df['Source'][ind]==510031)|(df['Source'][ind]==552988)):
            temp=df['Source'][ind]
            df['Source'][ind]=df['Target'][ind]
            df['Target'][ind]=temp
            print(df.iloc[ind])
df.to_csv('Q1-Graph4rew.csv',index=False)
# Out:
# <ipython-input-156-aa56d2ac8dba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Source'][ind]=df['Target'][ind]
# <ipython-input-156-aa56d2ac8dba>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'][ind]=temp
# Source               569329.00
# eType                     5.00
# Target               510031.00
# Time               31536000.00
# Weight                  498.36
# SourceLocation             NaN
# TargetLocation             NaN
# SourceLatitude             NaN
# SourceLongitude            NaN
# TargetLatitude             NaN
# TargetLongitude            NaN
# ...

# %%
df = pd.read_csv("./data/Q1-Graph5.csv")
for ind in df.index: 
    if(df['eType'][ind]==5):
        if((df['Source'][ind]==510031)|(df['Source'][ind]==552988)):
            temp=df['Source'][ind]
            df['Source'][ind]=df['Target'][ind]
            df['Target'][ind]=temp
            print(df.iloc[ind])
df.to_csv('Q1-Graph5rew.csv',index=False)
# Out:
# <ipython-input-157-1f160551b26a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Source'][ind]=df['Target'][ind]
# <ipython-input-157-1f160551b26a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'][ind]=temp
# Source               483784.00
# eType                     5.00
# Target               510031.00
# Time               31536000.00
# Weight                 1201.05
# SourceLocation             NaN
# TargetLocation             NaN
# SourceLatitude             NaN
# SourceLongitude            NaN
# TargetLatitude             NaN
# TargetLongitude            NaN
# ...

# %%
import pandas as pd
df = pd.read_csv("./data/Q1-Graph3rew.csv")
df1=df[(df['eType']<5)]
print(df1)
G = nx.from_pandas_edgelist(df1, 'Source', 'Target')
#G=nx.Graph()
layout = nx.shell_layout(G)

people = list(df1[(df1['eType']==1)|(df1['eType']==0)]['Source'].unique())

people =people+( list(df1[df1['eType']<=1]['Target'].unique()))
people =people+( list(df1[df1['eType']==2]['Source'].unique()))
people =people+( list(df1[df1['eType']==3]['Source'].unique()))
people =people+( list(df1[df1['eType']==4]['Source'].unique()))
people=list(set(people))
print(people)
item = list(df1[df1['eType']==2]['Target'].unique())
item = item+ list(df1[df1['eType']==3]['Target'].unique())

item=list(set(item))
book=list(df1[df1['eType']==4]['Target'].unique())
print(book)
print(item)
radii = [7,15,30,45,60]  # for concentric circles
label={}
for ea in layout.keys():
    new_r = 1
    if ea in  item:
        new_r = radii[3]
        label[ea]=""
    elif ea in people:
        new_r = radii[4]
        label[ea]=str(ea)
    elif ea in book:
        new_r = radii[1]
        label[ea]=str(ea)
    else:
        pass
    layout[ea] *= new_r 
nx.draw_networkx_labels(G, layout,labels=label)
nx.draw_networkx_nodes(G, layout,
                       nodelist=people,
                       node_color='r',
                       node_size=300,
                       alpha=0.8,with_labels=False)

nx.draw_networkx_nodes(G, layout,
                       nodelist=item,
                       node_color='b',
                       node_size=100,
                       alpha=0.8)
nx.draw_networkx_nodes(G, layout,
                       nodelist=book,
                       node_color='g',
                       node_size=100,
                       alpha=0.8)

nx.draw_networkx_edges(G, layout, width=1.0, alpha=0.5)

plt.axis('off')
#nx.draw(G, layout, width=1.0, alpha=0.5)
plt.show()
print(layout)
print(df1[df1['eType']==3])
# Out:
#      Source  eType  Target       Time  Weight  SourceLocation  TargetLocation  \
# 0    614761      4  514306 -209742644     0.1             NaN             NaN
# 1    614761      1  542965    1672686     1.0             1.0             2.0
# 2    538892      1  572391    1749455     1.0             2.0             2.0
# 3    538892      0  614761    2020424     1.0             NaN             NaN
# 4    614761      1  500813    2220686     1.0             1.0             1.0
# ..      ...    ...     ...        ...     ...             ...             ...
# 183  538892      0  541619   20000695     1.0             NaN             NaN
# 185  541619      0  544074   20033852     1.0             NaN             NaN
# 186  544074      0  538892   20064067     1.0             NaN             NaN
# 188  544074      1  541619   20128854     1.0             4.0             4.0
# 189  541619      0  538892   20176137     1.0             NaN             NaN
#
# ...

# %%
df = pd.read_csv("./data/Q1-Graph1rew.csv")
for ind in df.index: 
    if(df['eType'][ind]==5):
      
           
            df['Target'][ind]=str( df['Source'][ind])+"&"+str(df['Target'][ind])
            df['Color'][ind]
            print(df.iloc[ind])
df.to_csv('Q1-Graph1rew1.csv',index=False)
# Out:
# <ipython-input-9-9a739427cdac>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'][ind]=str( df['Source'][ind])+"&"+str(df['Target'][ind])
# c:\python38\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# Source                    608827
# eType                          5
# Target             608827&630626
# Time                    31536000
# Weight                   21699.3
# SourceLocation               NaN
# TargetLocation               NaN
# SourceLatitude               NaN
# ...

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
df = pd.read_csv("./data/Q1-Graph2rew.csv")
df1=df

df1['Time']=np.floor(df['Time']/86400).astype(int)
df1=df1.loc[3:500]
df1=df1[df1['eType']!=5]
people = list(df1[(df1['eType']==1)|(df1['eType']==0)]['Source'].unique())

people =people+( list(df1[df1['eType']<=1]['Target'].unique()))
people =people+( list(df1['Source'].unique()))

people=list(set(people))
p1=df[df['eType']==5].Source
cc=p1.isin(people).loc[lambda x : x==True].index

print()

df1=df1.append(df.loc[cc],ignore_index=True)
print(df1)
G = nx.from_pandas_edgelist(df1, 'Source', 'Target', edge_attr='eType')
#G=nx.Graph()
durations = [i['eType'] for i in dict(G.edges).values()]
colors = ['black','black','blue','blue','green','pink','brown']
print(durations)
color=list()
i=0
while i < len(durations):
    color.append(colors[durations[i]])
    i=i+1
layout = nx.circular_layout(G)
print('degree',G.degree(541017))


item = list(df1[df1['eType']==2]['Target'].unique())
item = item+ list(df1[df1['eType']==3]['Target'].unique())

item=list(set(item))
book=list(df1[df1['eType']==4]['Target'].unique())
travel=list(df1[df1['eType']==6]['Target'].unique())
demo=list(df1[df1['eType']==5]['Target'].unique())
print(book)
print(demo)
radii = [15,25,30,45,10]  # for concentric circles
label={}
for ea in layout.keys():
    new_r = 1
    if ea in  item:
        new_r = radii[1]
        label[ea]=""
    elif ea in people:
        new_r = radii[3]
        label[ea]=""
    elif ea in book:
        new_r = radii[0]
        label[ea]=""
    elif ea in travel:
        new_r = radii[2]
        label[ea]=""
    elif ea in demo:
        new_r = radii[4]
        label[ea]=""
    else:
        pass
    layout[ea] *= new_r 
nx.draw_networkx_labels(G, layout,labels=label)
nx.draw_networkx_nodes(G, layout,
                       nodelist=people,
                       node_color='r',
                       node_size=100,
                       alpha=0.8,with_labels=False)

nx.draw_networkx_nodes(G, layout,
                       nodelist=item,
                       node_color='b',
                       node_size=50,
                       alpha=0.8)
nx.draw_networkx_nodes(G, layout,
                       nodelist=book,
                       node_color='g',
                       node_size=100,
                       alpha=0.8)
nx.draw_networkx_nodes(G, layout,
                       nodelist=travel,
                       node_color='brown',
                       node_size=100,
                       alpha=0.8)
nx.draw_networkx_nodes(G, layout,
                       nodelist=demo,
                       node_color='grey',
                       node_size=1,
                       alpha=0.8)

nx.draw_networkx_edges(G, layout, width=0.2, alpha=1,edge_color=color)

plt.axis('off')
#nx.draw(G, layout, width=1.0, alpha=0.5)
plt.show()
print(layout)
print(df1[df1['eType']==3])
import base64
import io 
pic_IObytes = io.BytesIO()
plt.savefig(pic_IObytes,  format='png')
pic_IObytes.seek(0)
pic_hash = base64.b64encode(pic_IObytes.read())
imgdata=base64.b64decode(pic_IObytes.read())
filename = 'some_image.jpg'  # I assume you have a way of picking unique filenames
with open(filename, 'wb') as f:
    f.write(imgdata)
from PIL import Image
img = Image.open('some_image.jpg')
img.show()
# Out:
#      Source  eType  Target  Time       Weight  SourceLocation  TargetLocation  \
# 0    541017      4  601492  -746     0.142857             NaN             NaN
# 1    572413      1  629627    15     1.000000             4.0             4.0
# 2    572413      1  505965    15     1.000000             4.0             4.0
# 3    505965      0  629627    15     1.000000             NaN             NaN
# 4    572413      1  505965    15     1.000000             4.0             4.0
# ..      ...    ...     ...   ...          ...             ...             ...
# 799  527597      5  644226   365   981.940000             NaN             NaN
# 800  527597      5  632961   365   207.220000             NaN             NaN
# 801  527597      5  473173   365   820.070000             NaN             NaN
# 802  527597      5  620120   365  1277.460000             NaN             NaN
# 803  527597      5  621924   365   273.830000             NaN             NaN
#
# ...

# %%
nx.degree_centrality(G)
# Out:
# {541017: 0.5517241379310345,
#  601492: 0.017241379310344827,
#  572413: 0.48275862068965514,
#  629627: 0.6206896551724138,
#  505965: 0.5,
#  515794: 0.48275862068965514,
#  563211: 0.48275862068965514,
#  585212: 0.5172413793103449,
#  599441: 0.48275862068965514,
#  527597: 0.5,
#  582851: 0.5,
#  534034: 0.48275862068965514,
#  644830: 0.05172413793103448,
#  488928: 0.41379310344827586,
#  602912: 0.46551724137931033,
#  534449: 0.3448275862068966,
#  477138: 0.3793103448275862,
#  544615: 0.46551724137931033,
#  639051: 0.41379310344827586,
#  487668: 0.034482758620689655,
#  657173: 0.05172413793103448,
#  625756: 0.12068965517241378,
#  509607: 0.12068965517241378,
#  499467: 0.12068965517241378,
#  572391: 0.017241379310344827,
#  542965: 0.017241379310344827,
#  635665: 0.034482758620689655,
#  538892: 0.017241379310344827,
#  464459: 0.034482758620689655,
#  568093: 0.034482758620689655,
#  630626: 0.1896551724137931,
#  536346: 0.15517241379310345,
# ...

# %%
nx.eigenvector_centrality(G)
# Out:
# {541017: 0.19489719774177341,
#  601492: 0.00967002060916915,
#  572413: 0.1916392712402061,
#  629627: 0.25547494036315477,
#  505965: 0.20238301753696686,
#  515794: 0.19038632480370846,
#  563211: 0.1943146905746926,
#  585212: 0.1947349219297073,
#  599441: 0.18449164444275443,
#  527597: 0.20056867430169104,
#  582851: 0.2002038026275898,
#  534034: 0.18216592946908924,
#  644830: 0.016628090953565197,
#  488928: 0.12991371483223815,
#  602912: 0.19140769982726807,
#  534449: 0.15113998669517653,
#  477138: 0.16854348689522852,
#  544615: 0.19742243287444822,
#  639051: 0.17419972314380613,
#  487668: 0.01048702254287152,
#  657173: 0.030867808785126297,
#  625756: 0.04113742477068618,
#  509607: 0.0408313516580707,
#  499467: 0.04113742477068618,
#  572391: 0.00202591132118332,
#  542965: 0.00202591132118332,
#  635665: 0.0040821954526560535,
#  538892: 0.00202591132118332,
#  464459: 0.0040821954526560535,
#  568093: 0.0040821954526560535,
#  630626: 0.10027667450171404,
# ...

# %%
pd.Series(nx.eigenvector_centrality(G)).mean()
# Out:
# 0.11027799132866754

# %%
avgDict = {}
for k,v in nx.eigenvector_centrality(G).iteritems():
    # v is the list of grades for student k
    avgDict[k] = sum(v)/ float(len(v))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-90b746596a04> in <module>
#       1 avgDict = {}
# ----> 2 for k,v in nx.eigenvector_centrality(G).iteritems():
#       3     # v is the list of grades for student k
#       4     avgDict[k] = sum(v)/ float(len(v))
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
round(pd.Series(dict()).mean(),3)
# Out:
# <ipython-input-13-3975fff6a736>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   round(pd.Series(dict()).mean(),3)
# nan

# %%
pd.Series(nx.eigenvector_centrality(G)
# Out:
# 0.25547494036315477

# %%
pd.Series(nx.hits(G)[0]).mean()
# Out:
# 0.016949152542372885

# %%
value=''
switcher = {
   'a': 'hello'
}
value=switcher.get('a')
print(value)
# Out:
# hello

# %%
round(pd.Series(nx.katz_centrality_numpy(G)).mean(),3)
# Out:
# 0.05

# %%
import datetime
import time

# %%
d = datetime.date(2015,1,5)

unixtime = time.mktime(d.timetuple())

# %%
unixtime
# Out:
# 1420434000.0

# %%
a=datetime.datetime.utcfromtimestamp(unixtime)

# %%
a=a.strftime("%m/%d/%Y")

# %%
a
# Out:
# '01/05/2015'

# %%
df = pd.read_csv("./data/CGCS-Templaterew.csv")

# %%
df1=df[df['eType']==4]

# %%
df1= pd. DataFrame(df1)

# %%
df1.iloc[:,:5]
# Out:
#    Source  eType  Target  Time  Weight
# 0       0      4     -99   -99     -99

# %%
d = datetime.date(2025,1,1)

unixtime = time.mktime(d.timetuple())

# %%
unixtime
# Out:
# 1735707600.0

# %%
b=datetime.datetime.utcfromtimestamp(unixtime+df1.iloc[0]['Time']).strftime("%m/%d/%Y")

# %%
b
# Out:
# '05/10/2018'

# %%
df1.loc[0]['Time']=b
# Out:
# <ipython-input-66-f40090611fce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[0]['Time']=b

# %%
list(nx.in_degree(G)).v
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4e0de38c9580> in <module>
# ----> 1 list(nx.in_degree(G)).v
#
# AttributeError: module 'networkx' has no attribute 'in_degree'

# %%
round(pd.Series(nx.degree(G)[0]).mean(),3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c45a8400db50> in <module>
# ----> 1 round(pd.Series(nx.degree(G)[0]).mean(),3)
#
# c:\python38\lib\site-packages\networkx\classes\reportviews.py in __getitem__(self, n)
#     434     def __getitem__(self, n):
#     435         weight = self._weight
# --> 436         nbrs = self._succ[n]
#     437         if weight is None:
#     438             return len(nbrs) + (n in nbrs)
#
# KeyError: 0

# %%
nx.degree(G)
# Out:
# DegreeView({541017: 32, 601492: 1, 572413: 28, 629627: 36, 505965: 29, 515794: 28, 563211: 28, 585212: 30, 599441: 28, 527597: 29, 582851: 29, 534034: 28, 644830: 3, 488928: 24, 602912: 27, 534449: 20, 477138: 22, 544615: 27, 639051: 24, 487668: 2, 657173: 3, 625756: 7, 509607: 7, 499467: 7, 572391: 1, 542965: 1, 635665: 2, 538892: 1, 464459: 2, 568093: 2, 630626: 11, 536346: 9, 520660: 8, 552988: 17, 567195: 16, 527449: 17, 459381: 17, 595298: 17, 466907: 15, 577992: 10, 537281: 12, 523927: 12, 580426: 14, 595581: 15, 503701: 14, 571970: 9, 644226: 9, 473173: 17, 620120: 15, 575030: 9, 621924: 10, 640784: 3, 616315: 9, 642329: 12, 632961: 11, 510031: 5, 589943: 12, 503218: 3, 606730: 2})

# %%
degrees = pd.Series([val for (node, val) in G.degree()]).mean()
degrees
pd.Series(list(nx.average_neighbor_degree(G).values())).mean()
# Out:
# 21.81183083600702

# %%
G.number_of_nodes()
# Out:
# 59

# %%
G.number_of_edges()
# Out:
# 419

# %%
n1 = float("nan")

# %%
n1-0
# Out:
# nan

# %%
a=[]
a.append('b')

# %%
a
# Out:
# ['b']

# %%
len(G)
# Out:
# 59

# %%
float('inf')-10000000000000
# Out:
# inf

# %%
import sys
sys.maxsize
# Out:
# 9223372036854775807

# %%
abs(-1)
# Out:
# 1

# %%
(0.000695-0.00000)/((0.000695-0.00000))
# Out:
# 1.0
